# %%
# !pip install rdflib 
github_storage = "https://raw.githubusercontent.com/FacultadInformatica-LinkedData/Curso2020-2021/master/Assignment4"
# Out:
# ...
#      |████████████████████████████████| 235kB 2.8MB/s
# ...
#      |████████████████████████████████| 51kB 4.7MB/s
# ...

# %%
from rdflib import Graph, Namespace, Literal
from rdflib.namespace import RDF, RDFS
g = Graph()

# %%
URI_domain = Namespace("http://www.publicProcurementMurciaCOVID19.es/")
Ontology_path = "http://www.publicProcurementMurciaCOVID19.es/ontology/"
on = Namespace("http://www.publicProcurementMurciaCOVID19.es/ontology/on#")
Individual_path = "http://www.publicProcurementMurciaCOVID19.es/resource/"

Company = Namespace("https://www.w3.org/ns/prov#").Organization
Date = Namespace("http://dbpedia.org/ontology/date")
Location = Namespace("https://www.w3.org/ns/prov#")

g = Graph()

g.add((on.Order, RDF.type, RDFS.Class))
g.add((on.Medical_service, RDF.type, RDFS.Class))
g.add((on.Medical_supply, RDF.type, RDFS.Class))
g.add((on.COVID19_status, RDF.type, RDFS.Class))
g.add((on.Date, RDF.type, RDFS.Class))
g.add((Company, RDF.type, RDFS.Class))
g.add((on.isService, RDF.type, RDF.Property))
g.add((on.isSupply, RDF.type, RDF.Property))
g.add((on.hasSupplier, RDF.type, RDF.Property))
g.add((on.inDate, RDF.type, RDF.Property))
g.add((on.makesOrder, RDF.type, RDF.Property))
g.add((on.hasCOVIDStatus, RDF.type, RDF.Property))
g.add((on.CCAA, RDFS.subClassOf, Location.location))
g.add((on.hasNIF, RDF.type, RDF.Property))
g.add((on.hasName, RDF.type, RDF.Property))
g.add((on.hasOrderAmount, RDF.type, RDF.Property))
g.add((on.hasPaidAmount, RDF.type, RDF.Property))
g.add((on.hasPendingAmount, RDF.type, RDF.Property))
g.add((on.hasProductQuantity, RDF.type, RDF.Property))
g.add((on.hasProductQuantityReceived, RDF.type, RDF.Property))
g.add((on.hasProductQuantityPending, RDF.type, RDF.Property))
g.add((on.hasIVA, RDF.type, RDF.Property))
g.add((on.hasISOCode, RDF.type, RDF.Property))
g.add((on.TotalCases, RDF.type, RDF.Property))
g.add((on.numPCR, RDF.type, RDF.Property))
g.add((on.numAC, RDF.type, RDF.Property))
g.add((on.numOthers, RDF.type, RDF.Property))
g.add((on.numUnknown, RDF.type, RDF.Property))
g.add((on.Hospitalizations, RDF.type, RDF.Property))
g.add((on.UCI, RDF.type, RDF.Property))
g.add((on.Deaths, RDF.type, RDF.Property))

g.add((on.order1, RDF.type, on.Order))
g.add((on.Murcia, RDF.type, on.CCAA))
g.add((on.Murcia, on.hasISOCode, Literal("MC")))
g.add((on.Murcia, on.makesOrder, on.order1))

g.add((on.ManuelPerezTalavera, RDF.type, Company))
g.add((on.order1, on.hasSupplier, on.ManuelPerezTalavera))

g.add((on.ManuelPerezTalavera, on.hasNIF, Literal("***3520**")))
g.add((on.ManuelPerezTalavera, on.hasName, Literal("Manuel Perez Talavera")))

g.add((on.order1, on.hasOrderAmount, Literal(3)))
g.add((on.order1, on.hasPaidAmount, Literal(3)))
g.add((on.order1, on.hasPendingAmount, Literal(0)))
g.add((on.order1, on.hasProductQuantity, Literal(26)))
g.add((on.order1, on.hasProductQuantityReceived, Literal(26)))
g.add((on.order1, on.hasProductQuantityPending, Literal(0)))
g.add((on.order1, on.hasIVA, Literal(21)))

g.add((on.GafasProteccion, RDF.type, on.Medical_supply))
g.add((on.GafasProteccion, on.hasName, Literal("GAFAS DE PROTECCION")))
g.add((on.order1, on.isSupply, on.GafasProteccion))

g.add((on.fecha1, RDF.type, on.Date))
g.add((on.fecha1, on.hasDate, Literal("16/03/2020")))
g.add((on.order1, on.hasDate, on.fecha1))



#g.add((o1, hasSupplier, c1))

print(g.serialize(format="ttl").decode("UTF-8"))
# Out:
# @prefix ns1: <http://www.publicProcurementMurciaCOVID19.es/ontology/on#> .
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#> .
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#> .
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#> .
#
# ns1:COVID19_status a rdfs:Class .
#
# ns1:Date a rdfs:Class .
#
# ns1:Medical_service a rdfs:Class .
#
# ns1:Medical_supply a rdfs:Class .
#
# ns1:Order a rdfs:Class .
#
# <https://www.w3.org/ns/prov#Organization> a rdfs:Class .
#
# ns1:Deaths a rdf:Property .
#
# ns1:Hospitalizations a rdf:Property .
#
# ns1:Murcia a ns1:CCAA ;
#     ns1:hasISOCode "MC" ;
#     ns1:makesOrder ns1:order1 .
#
# ns1:TotalCases a rdf:Property .
#
# ns1:UCI a rdf:Property .
#
# ns1:hasCOVIDStatus a rdf:Property .
#
# ns1:hasISOCode a rdf:Property .
#
# ns1:hasIVA a rdf:Property .
#
# ns1:hasNIF a rdf:Property .
#
# ns1:hasName a rdf:Property .
#
# ns1:hasOrderAmount a rdf:Property .
#
# ns1:hasPaidAmount a rdf:Property .
#
# ...
